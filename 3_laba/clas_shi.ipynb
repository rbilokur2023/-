# %% [markdown]
# Наша карта: Wizard з атакою 5 та здоровям 24
# Ворожа карта: Wizard з атакою 12 та здоровям 20
# Раунд 1:
# Wizard атакує Wizard. Wizard залишилось 12 здоров'я!
# Wizard атакує Wizard. Wizard залишилось 15 здоров'я!
# Раунд 2:
# Wizard атакує Wizard. Wizard залишилось 10 здоров'я!
# Wizard захищається, здоров'я відновилось до 12!
# Раунд 3:
# Wizard захищається, здоров'я відновилось до 14!
# Wizard атакує Wizard. Wizard залишилось 2 здоров'я!
# Раунд 4:
# Wizard захищається, здоров'я відновилось до 14!
# Wizard захищається, здоров'я відновилось до 4!
# Раунд 5:
# Wizard атакує Wizard. Wizard залишилось -8 здоров'я!
# Wizard захищається, здоров'я відновилось до -6!
# Wizard програв!

# %%
import random

class CardGame:
    CARD_NAMES = ["Dragon", "Knight", "Wizard", "Goblin", "Elf"]
    def __init__(self):
        self.name = random.choice(self.CARD_NAMES)
        self.attack_power = random.randint(5, 15)
        self.health = random.randint(20, 30)
    
    def attack(self, other_card): 
        other_card.health -= self.attack_power
        return f"{self.name} атакує {other_card.name}. {other_card.name} залишилось {other_card.health} здоров'я!"
    
    def defend(self):
        self.health += 2
        return f"{self.name} захищається, здоров'я відновилось до {self.health}!"
    
    def make_move(self, other_card):
        if random.choice([True, False]):
            return self.attack(other_card)
        else:
            return self.defend()
    
player_1 = CardGame()
print(f"Наша карта: {player_1.name} з атакою {player_1.attack_power} та здоровям {player_1.health}")

player_2 = CardGame()
print(f"Ворожа карта: {player_2.name} з атакою {player_2.attack_power} та здоровям {player_2.health}")

def shuffle_moves(player_1, player_2):
    if random.choice([True, False]):
        print(player_1.make_move(player_2))
        print(player_2.make_move(player_1))
    else:
        print(player_2.make_move(player_1))
        print(player_1.make_move(player_2))

for i in range(1, 10):
    print(f"Раунд {i}:")
    shuffle_moves(player_1, player_2)
    if player_1.health <= 0:
        print(f"{player_1.name} програв!")
        break
    elif player_2.health <= 0:
        print(f"{player_2.name} програв!")
        break

# %% [markdown]
# - І накінець ми створили міні гру, де нам випадають ітеми або карти, якими можуть бути зброя, і ми робимо ходи цими картами, де карти атакують одна одну з attack_power та зменшують одна одній durability

# %% [markdown]
# This is public
# Modified private
# ['_Item__protected_attribute', '__add__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_private_attribute', 'get_protected_attribute', 'method_with_private_var', 'number', 'public_attribute']
# This is protected

# %%
class Item:
    def __init__(self):
        self.number = random.randint(1,100)
        self.public_attribute = "This is public"
        self._private_attribute = "This is private"
        self.__protected_attribute = "This is protected"
    
    def __add__(self, other: Item):
        return self.number + other.number
    
    def __str__(self):
        return f"Це вивід обєкта класу Item з числом {self.number}"
    
    def __len__(self):
        return self.number % 10

    @staticmethod
    def method_with_private_var():
        _a = 0
        if random.randint(0,1):
            _a += 1
        else:
            _a += 5
        return _a
    
    @property
    def get_protected_attribute(self):
        return self.__protected_attribute

c = Item()
print(c.public_attribute)          # Доступ до публічного атрибута
c._private_attribute = "Modified private" # Модифікація захищеного атрибута не заборонена, але можлива
print(c._private_attribute)         # Доступ до захищеного атрибута
print(dir(c))
print(c.get_protected_attribute) # Доступ до приватного атрибута

# %% [markdown]
# - приватні, захищені та публічні атрибути та приховування даних

# %% [markdown]
# Створено обєкт класу Sword з міцністю 100
# 40 modified

# %%
class Item:
    def __init__(self):
        # тепер для кожного обєкта є характерним дані атрибути
        self._initial_durability = random.randint(30, 45)
        self.name = random.choice(["trash", "Axe", "Sword", "Spear", "Bow", "Knife"])

    @classmethod
    def modify_class_durability(cls, new_durability):
        _a = cls()
        _a._initial_durability = new_durability
        _a.type = "modified"
        print(f"Створено обєкт класу {_a.name} з міцністю {_a._initial_durability}")
        return _a
a = Item()
b = Item.modify_class_durability(100)
print(a._initial_durability, b.type)

# %% [markdown]
# Альтернативні конструктори та класові методи

# %% [markdown]
# <class 'type'> <class '__main__.Item'>
# Bow має міцність 45 Bow має міцність 45
# Hello from Item class! Hello from Item class!

# %%
class Item:
    global_item_count = 0  # класова змінна
    """Це наш клас який описує ітем в грі"""
    def __init__(self):
        # тепер для кожного обєкта є характерним дані атрибути
        self._initial_durability = random.randint(30, 45)
        self.name = random.choice(["trash", "Axe", "Sword", "Spear", "Bow", "Knife"])

    def test_method(self):
        Item.global_item_count += 1
        return f"{self.name} має міцність {self._initial_durability}"
    
    @staticmethod
    def always_say_hello():
        return "Hello from Item class!"
i = Item
b = Item()
print(type(i), type(b))
print(b.test_method(), i.test_method(b))
print(b.always_say_hello(), i.always_say_hello())

# %% [markdown]
# Після цього ми розглядали Методи та статичні методи, змінна self

# %%
class Item:
    """Це наш клас який описує ітем в грі"""
    def __init__(self):
        # тепер для кожного обєкта є характерним дані атрибути
        self._initial_durability = random.randint(30, 45)
        self.name = random.choice(["trash", "Axe", "Sword", "Spear", "Bow", "Knife"])
        self.rarity = "green"
        self.attack_power = random.randint(4, 6)
        self.durability = self._initial_durability
        self.magic_attribute = "Магія Природи"
        self.description = "Рандомний предмет зброї"
    
    @property
    def get_attack_power(self):
        return self.attack_power
    
    @property
    def get_current_durability(self):
        return f"{self.name} має міцність {self.durability}/{self._initial_durability}"
    
card = Item()
print(f"{card.attack_power} = {card.get_attack_power}")
card.attack_power += 1
print(card.attack_power, card.get_attack_power)
5 = 5
6 6

# %% [markdown]
# Далі ми розглянули властивості (Property)

# %% [markdown]
# Подія 0: Нам випав ітем:
#               Spear з параметрами:
#               Атака/захист: 6/37
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Spear наніс 8 шкоди типом Магія Природи
#
#             Подія 1: Нам випав ітем:
#               Bow з параметрами:
#               Атака/захист: 6/40
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Bow захищається та відновлює міцність до 1
#
#             Подія 2: Нам випав ітем:
#               Bow з параметрами:
#               Атака/захист: 4/44
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Bow захищається та відновлює міцність до 1
#
#             Подія 3: Нам випав ітем:
#               trash з параметрами:
#               Атака/захист: 4/37
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: trash наніс 6 шкоди типом Магія Природи
#
#             Подія 4: Нам випав ітем:
#               Sword з параметрами:
#               Атака/захист: 4/35
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Sword захищається та відновлює міцність до 1
#
#             Подія 5: Нам випав ітем:
#               Axe з параметрами:
#               Атака/захист: 6/43
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Axe захищається та відновлює міцність до 1
#
#             Подія 6: Нам випав ітем:
#               Spear з параметрами:
#               Атака/захист: 4/40
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Spear наніс 6 шкоди типом Магія Природи
#
#             Подія 7: Нам випав ітем:
#               trash з параметрами:
#               Атака/захист: 4/44
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: trash захищається та відновлює міцність до 1
#
#             Подія 8: Нам випав ітем:
#               Bow з параметрами:
#               Атака/захист: 6/45
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Bow наніс 8 шкоди типом Магія Природи
#
#             Подія 9: Нам випав ітем:
#               Sword з параметрами:
#               Атака/захист: 4/36
#               Магічними властивостями: Магія Природи
#
# Застосовуємо предмет: Sword захищається та відновлює міцність до 1

# %%
import random
class Item:
    """Це наш клас який описує ітем в грі"""
    def __init__(self):
        # тепер для кожного обєкта є характерним дані атрибути
        self.name = random.choice(["trash", "Axe", "Sword", "Spear", "Bow", "Knife"])
        self.rarity = "green"
        self.attack_power = random.randint(4, 6)
        self.durability = random.randint(30, 45)
        self.magic_attribute = "Магія Природи"
        self.description = "Рандомний предмет зброї"
    
    def attack(self):
        if "Магія" in self.magic_attribute:
            attack = self.attack_power + 2
        return f"{self.name} наніс {attack} шкоди типом {self.magic_attribute}"
    
    def defence(self):
        self.durability =+ 1
        return f"{self.name} захищається та відновлює міцність до {self.durability}"
        

for i in range(10):
    item = Item()
    print(f"""
            Подія {i}: Нам випав ітем:
              {item.name} з параметрами:
              Атака/захист: {item.attack_power}/{item.durability}
              Магічними властивостями: {item.magic_attribute}
            """)
    if random.randint(0,1):
        print(f"Застосовуємо предмет: {item.attack()}")
    else:
        print(f"Застосовуємо предмет: {item.defence()}")

# %% [markdown]
# Приклади з лекцій:
# Створено клас Item для моделювання ігрового предмета з випадковими характеристиками. Реалізовано методи атаки та захисту, а також цикл, який генерує та використовує 10 різних предметів. Робота демонструє використання класів, об’єктів та модуля random у Python.
